# %% [markdown]
# # Diabetes Prediction with AutoGluon_ :Gaurav Singh
# This notebook walks through data preprocessing, exploration, and model building using AutoGluon.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv('diabetes_dataset.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#    Age     Sex Ethnicity   BMI  Waist_Circumference  Fasting_Blood_Glucose  \
# 0   58  Female     White  35.8                 83.4                  123.9
# 1   48    Male     Asian  24.1                 71.4                  183.7
# 2   34  Female     Black  25.0                113.8                  142.0
# 3   62    Male     Asian  32.7                100.4                  167.4
# 4   27  Female     Asian  33.5                110.8                  146.4
#
#    HbA1c  Blood_Pressure_Systolic  Blood_Pressure_Diastolic  \
# 0   10.9                      152                       114
# 1   12.8                      103                        91
# 2   14.5                      179                       104
# 3    8.8                      176                       118
# 4    7.1                      122                        97
#
#    Cholesterol_Total  Cholesterol_HDL  Cholesterol_LDL   GGT  Serum_Urate  \
# 0              197.8             50.2             99.2  37.5          7.2
# 1              261.6             62.0            146.4  88.5          6.1
# 2              261.0             32.1            164.1  56.2          6.9
# 3              183.4             41.1             84.0  34.4          5.4
# 4              203.2             53.9             92.8  81.9          7.4
#
#   Physical_Activity_Level  Dietary_Intake_Calories Alcohol_Consumption  \
# 0                Moderate                     1538            Moderate
# 1                Moderate                     2653            Moderate
# 2                     Low                     1684               Heavy
# 3                     Low                     3796            Moderate
# 4                Moderate                     3161               Heavy
#
#   Smoking_Status  Family_History_of_Diabetes  Previous_Gestational_Diabetes
# 0          Never                           0                              1
# 1        Current                           0                              1
# 2         Former                           1                              0
# 3          Never                           1                              0
# 4        Current                           0                              0

# %% [markdown]
# ## Check for Missing Values

# %%
df.isnull().sum()
# Out:
# Age                                 0
# Sex                                 0
# Ethnicity                           0
# BMI                                 0
# Waist_Circumference                 0
# Fasting_Blood_Glucose               0
# HbA1c                               0
# Blood_Pressure_Systolic             0
# Blood_Pressure_Diastolic            0
# Cholesterol_Total                   0
# Cholesterol_HDL                     0
# Cholesterol_LDL                     0
# GGT                                 0
# Serum_Urate                         0
# Physical_Activity_Level             0
# Dietary_Intake_Calories             0
# Alcohol_Consumption              3320
# Smoking_Status                      0
# Family_History_of_Diabetes          0
# Previous_Gestational_Diabetes       0
# dtype: int64

# %%
df['Alcohol_Consumption'] = df['Alcohol_Consumption'].fillna(df['Alcohol_Consumption'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Age                              0
# Sex                              0
# Ethnicity                        0
# BMI                              0
# Waist_Circumference              0
# Fasting_Blood_Glucose            0
# HbA1c                            0
# Blood_Pressure_Systolic          0
# Blood_Pressure_Diastolic         0
# Cholesterol_Total                0
# Cholesterol_HDL                  0
# Cholesterol_LDL                  0
# GGT                              0
# Serum_Urate                      0
# Physical_Activity_Level          0
# Dietary_Intake_Calories          0
# Alcohol_Consumption              0
# Smoking_Status                   0
# Family_History_of_Diabetes       0
# Previous_Gestational_Diabetes    0
# dtype: int64

# %% [markdown]
# ## Explore Categorical Features

# %%
for col in df.select_dtypes(include='object').columns:
    print(f'{col}: {df[col].unique()}')
# Out:
# Sex: ['Female' 'Male']
# Ethnicity: ['White' 'Asian' 'Black' 'Hispanic']
# Physical_Activity_Level: ['Moderate' 'Low' 'High']
# Alcohol_Consumption: ['Moderate' 'Heavy']
# Smoking_Status: ['Never' 'Current' 'Former']

# %% [markdown]
# ## Create the Target Column

# %%
df['Diabetes'] = df.apply(
    lambda row: 1 if row['Fasting_Blood_Glucose'] >= 126 or row['HbA1c'] >= 6.5 else 0,
    axis=1
)

# %% [markdown]
# ## Basic Visualization

# %%
sns.countplot(x='Diabetes', data=df)
plt.title('Diabetes Distribution')
plt.show()

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# %% [markdown]
# ## Train AutoGluon TabularPredictor

# %%
from autogluon.tabular import TabularPredictor

predictor = TabularPredictor(label='Diabetes').fit(train_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20250425_161552"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.0
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       2.11 GB / 15.34 GB (13.8%)
# Disk Space Avail:   48.95 GB / 231.24 GB (21.2%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# 	presets='good'         : Good accuracy with very fast inference speed.
# 	presets='medium'       : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "C:\Users\Offic\OneDrive\Desktop\C+\Diabetes_Prediction\Cleaned Version\AutogluonModels\ag-20250425_161552"
# Train Data Rows:    8000
# Train Data Columns: 20
# Label Column:       Diabetes
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [1, 0]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2177.61 MB
# 	Train Data (Original)  Memory Usage: 3.31 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 9 | ['BMI', 'Waist_Circumference', 'Fasting_Blood_Glucose', 'HbA1c', 'Cholesterol_Total', ...]
# 		('int', [])    : 6 | ['Age', 'Blood_Pressure_Systolic', 'Blood_Pressure_Diastolic', 'Dietary_Intake_Calories', 'Family_History_of_Diabetes', ...]
# 		('object', []) : 5 | ['Sex', 'Ethnicity', 'Physical_Activity_Level', 'Alcohol_Consumption', 'Smoking_Status']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['Ethnicity', 'Physical_Activity_Level', 'Smoking_Status']
# 		('float', [])     : 9 | ['BMI', 'Waist_Circumference', 'Fasting_Blood_Glucose', 'HbA1c', 'Cholesterol_Total', ...]
# 		('int', [])       : 4 | ['Age', 'Blood_Pressure_Systolic', 'Blood_Pressure_Diastolic', 'Dietary_Intake_Calories']
# 		('int', ['bool']) : 4 | ['Sex', 'Alcohol_Consumption', 'Family_History_of_Diabetes', 'Previous_Gestational_Diabetes']
# 	0.1s = Fit runtime
# 	20 features in original data used to generate 20 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.85 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 7200, Val Rows: 800
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif ...
# 	0.89	 = Validation score   (accuracy)
# 	3.56s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.8888	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.9988	 = Validation score   (accuracy)
# 	0.81s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# 	1.0	 = Validation score   (accuracy)
# 	0.4s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	1.0	 = Validation score   (accuracy)
# 	0.98s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	1.0	 = Validation score   (accuracy)
# 	0.64s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ...
# 	1.0	 = Validation score   (accuracy)
# 	13.79s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.9587	 = Validation score   (accuracy)
# 	0.61s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.9625	 = Validation score   (accuracy)
# 	0.6s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.995	 = Validation score   (accuracy)
# 	6.61s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost ...
# 	1.0	 = Validation score   (accuracy)
# 	0.62s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.9925	 = Validation score   (accuracy)
# 	13.09s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	1.0	 = Validation score   (accuracy)
# 	1.03s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'LightGBM': 1.0}
# 	1.0	 = Validation score   (accuracy)
# 	0.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 43.61s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 144762.2 rows/s (800 batch size)
# Disabling decision threshold calibration for metric `accuracy` due to having fewer than 10000 rows of validation data for calibration, to avoid overfitting (800 rows).
# 	`accuracy` is generally not improved through threshold calibration. Force calibration via specifying `calibrate_decision_threshold=True`.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("C:\Users\Offic\OneDrive\Desktop\C+\Diabetes_Prediction\Cleaned Version\AutogluonModels\ag-20250425_161552")

# %% [markdown]
# ## Model Evaluation

# %%
predictor.evaluate(test_data)
# Out:
# {'accuracy': 1.0,
#  'balanced_accuracy': 1.0,
#  'mcc': 1.0,
#  'roc_auc': 1.0,
#  'f1': 1.0,
#  'precision': 1.0,
#  'recall': 1.0}

# %% [markdown]
# ## Feature Importance

# %%
predictor.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 20 features using 2000 rows with 5 shuffle sets...
# 	1.42s	= Expected runtime (0.28s per shuffle set)
# 	0.38s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                importance    stddev       p_value  n  \
# HbA1c                              0.1455  0.004937  1.588372e-07  5
# Fasting_Blood_Glucose              0.1089  0.004736  4.279967e-07  5
# Age                                0.0000  0.000000  5.000000e-01  5
# Cholesterol_LDL                    0.0000  0.000000  5.000000e-01  5
# Family_History_of_Diabetes         0.0000  0.000000  5.000000e-01  5
# Smoking_Status                     0.0000  0.000000  5.000000e-01  5
# Alcohol_Consumption                0.0000  0.000000  5.000000e-01  5
# Dietary_Intake_Calories            0.0000  0.000000  5.000000e-01  5
# Physical_Activity_Level            0.0000  0.000000  5.000000e-01  5
# Serum_Urate                        0.0000  0.000000  5.000000e-01  5
# GGT                                0.0000  0.000000  5.000000e-01  5
# Cholesterol_HDL                    0.0000  0.000000  5.000000e-01  5
# Sex                                0.0000  0.000000  5.000000e-01  5
# Cholesterol_Total                  0.0000  0.000000  5.000000e-01  5
# Blood_Pressure_Diastolic           0.0000  0.000000  5.000000e-01  5
# Blood_Pressure_Systolic            0.0000  0.000000  5.000000e-01  5
# Waist_Circumference                0.0000  0.000000  5.000000e-01  5
# BMI                                0.0000  0.000000  5.000000e-01  5
# Ethnicity                          0.0000  0.000000  5.000000e-01  5
# Previous_Gestational_Diabetes      0.0000  0.000000  5.000000e-01  5
#
#                                p99_high   p99_low
# HbA1c                          0.155666  0.135334
# Fasting_Blood_Glucose          0.118650  0.099150
# Age                            0.000000  0.000000
# Cholesterol_LDL                0.000000  0.000000
# Family_History_of_Diabetes     0.000000  0.000000
# Smoking_Status                 0.000000  0.000000
# Alcohol_Consumption            0.000000  0.000000
# Dietary_Intake_Calories        0.000000  0.000000
# Physical_Activity_Level        0.000000  0.000000
# Serum_Urate                    0.000000  0.000000
# GGT                            0.000000  0.000000
# Cholesterol_HDL                0.000000  0.000000
# Sex                            0.000000  0.000000
# Cholesterol_Total              0.000000  0.000000
# Blood_Pressure_Diastolic       0.000000  0.000000
# Blood_Pressure_Systolic        0.000000  0.000000
# Waist_Circumference            0.000000  0.000000
# BMI                            0.000000  0.000000
# Ethnicity                      0.000000  0.000000
# Previous_Gestational_Diabetes  0.000000  0.000000

# %% [markdown]
# **Make Predictions**

# %%
#final prediction is being done using AutoGluon’s TabularPredictor, which internally selects the best model or ensemble based on performance on validation data.**

# %%
predictions = predictor.predict(test_data)
predictions.head()
# Out:
# 6252    1
# 4684    1
# 1731    1
# 4742    0
# 4521    1
# Name: Diabetes, dtype: int64

# %%
# Too check all models

# %%
predictor.leaderboard(silent=False)
# Out:
#                   model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0              LightGBM    1.00000    accuracy       0.004519   0.399377                0.004519           0.399377            1       True          4
# 1         LightGBMLarge    1.00000    accuracy       0.005025   1.030073                0.005025           1.030073            1       True         13
# 2   WeightedEnsemble_L2    1.00000    accuracy       0.005526   0.466538                0.001008           0.067162            2       True         14
# 3               XGBoost    1.00000    accuracy       0.007009   0.615141                0.007009           0.615141            1       True         11
# 4              CatBoost    1.00000    accuracy       0.007015  13.787992                0.007015          13.787992            1       True          7
# 5      RandomForestGini    1.00000    accuracy       0.050056   0.979580                0.050056           0.979580            1       True          5
# 6      RandomForestEntr    1.00000    accuracy       0.060747   0.639570                0.060747           0.639570            1       True          6
# 7            LightGBMXT    0.99875    accuracy       0.004002   0.812731                0.004002           0.812731            1       True          3
# 8       NeuralNetFastAI    0.99500    accuracy       0.020989   6.609612                0.020989           6.609612            1       True         10
# 9        NeuralNetTorch    0.99250    accuracy       0.011136  13.093711                0.011136          13.093711            1       True         12
# 10       ExtraTreesEntr    0.96250    accuracy       0.049169   0.604842                0.049169           0.604842            1       True          9
# 11       ExtraTreesGini    0.95875    accuracy       0.050089   0.612917                0.050089           0.612917            1       True          8
# 12       KNeighborsUnif    0.89000    accuracy       0.020372   3.559443                0.020372           3.559443            1       True          1
# 13       KNeighborsDist    0.88875    accuracy       0.018395   0.012651                0.018395           0.012651            1       True          2
#                   model  score_val eval_metric  pred_time_val   fit_time  \
# 0              LightGBM    1.00000    accuracy       0.004519   0.399377
# 1         LightGBMLarge    1.00000    accuracy       0.005025   1.030073
# 2   WeightedEnsemble_L2    1.00000    accuracy       0.005526   0.466538
# 3               XGBoost    1.00000    accuracy       0.007009   0.615141
# 4              CatBoost    1.00000    accuracy       0.007015  13.787992
# 5      RandomForestGini    1.00000    accuracy       0.050056   0.979580
# 6      RandomForestEntr    1.00000    accuracy       0.060747   0.639570
# 7            LightGBMXT    0.99875    accuracy       0.004002   0.812731
# 8       NeuralNetFastAI    0.99500    accuracy       0.020989   6.609612
# 9        NeuralNetTorch    0.99250    accuracy       0.011136  13.093711
# 10       ExtraTreesEntr    0.96250    accuracy       0.049169   0.604842
# 11       ExtraTreesGini    0.95875    accuracy       0.050089   0.612917
# 12       KNeighborsUnif    0.89000    accuracy       0.020372   3.559443
# 13       KNeighborsDist    0.88875    accuracy       0.018395   0.012651
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.004519           0.399377            1       True
# 1                 0.005025           1.030073            1       True
# 2                 0.001008           0.067162            2       True
# 3                 0.007009           0.615141            1       True
# 4                 0.007015          13.787992            1       True
# 5                 0.050056           0.979580            1       True
# 6                 0.060747           0.639570            1       True
# 7                 0.004002           0.812731            1       True
# 8                 0.020989           6.609612            1       True
# 9                 0.011136          13.093711            1       True
# 10                0.049169           0.604842            1       True
# 11                0.050089           0.612917            1       True
# 12                0.020372           3.559443            1       True
# 13                0.018395           0.012651            1       True
#
#     fit_order
# 0           4
# 1          13
# 2          14
# 3          11
# 4           7
# 5           5
# 6           6
# 7           3
# 8          10
# 9          12
# 10          9
# 11          8
# 12          1
# 13          2

# %% [markdown]
# **Prediction using XGBoost Model**

# %%
predictions = predictor.predict(test_data, model='XGBoost')

# %%
print(predictions.head())  # If it's a pandas Series or DataFrame
# Out:
# 6252    1
# 4684    1
# 1731    1
# 4742    0
# 4521    1
# Name: Diabetes, dtype: int64

# %%
test_data_with_preds = test_data.copy()
test_data_with_preds['Prediction'] = predictions
print(test_data_with_preds.head())
# Out:
#       Age     Sex Ethnicity   BMI  Waist_Circumference  Fasting_Blood_Glucose  \
# 6252   50    Male     Black  27.7                107.9                  172.6
# 4684   25    Male     White  27.6                 85.5                   95.8
# 1731   56    Male     White  35.3                 83.8                  145.2
# 4742   54  Female     White  39.8                 74.9                  105.8
# 4521   50  Female     White  32.0                 84.9                  150.6
#
#       HbA1c  Blood_Pressure_Systolic  Blood_Pressure_Diastolic  \
# 6252   14.3                      149                       117
# 4684   13.3                      122                        94
# 1731   14.0                      178                        94
# 4742    4.3                      145                        64
# 4521    6.9                      116                        79
#
#       Cholesterol_Total  ...   GGT  Serum_Urate  Physical_Activity_Level  \
# 6252              281.8  ...  64.9          6.8                 Moderate
# 4684              178.5  ...  27.1          3.5                     High
# 1731              182.1  ...  48.9          5.1                     High
# 4742              160.0  ...  38.9          3.8                     High
# 4521              194.4  ...  38.7          6.9                     High
#
#       Dietary_Intake_Calories Alcohol_Consumption  Smoking_Status  \
# 6252                     2466               Heavy          Former
# 4684                     3105            Moderate           Never
# 1731                     2434               Heavy           Never
# 4742                     3198            Moderate         Current
# 4521                     2205               Heavy           Never
#
#      Family_History_of_Diabetes Previous_Gestational_Diabetes  Diabetes  \
# 6252                          1                             1         1
# 4684                          1                             0         1
# 1731                          1                             0         1
# 4742                          0                             0         0
# 4521                          1                             1         1
#
#       Prediction
# 6252           1
# 4684           1
# 1731           1
# 4742           0
# 4521           1
#
# [5 rows x 22 columns]

# %%
from sklearn.metrics import accuracy_score, classification_report

y_true = test_data['Diabetes']
y_pred = predictions

print("Accuracy:", accuracy_score(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# Accuracy: 0.9995
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       181
#            1       1.00      1.00      1.00      1819
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000

# %% [markdown]
# **we can now visualize performance using a plot like a confusion matrix:**

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_auc_score, roc_curve

y_probs = predictor.predict_proba(test_data)[1]  # Probability of class 1
fpr, tpr, _ = roc_curve(y_true, y_probs)
plt.plot(fpr, tpr, label='ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

print("AUC Score:", roc_auc_score(y_true, y_probs))
# Out:
# AUC Score: 1.0
